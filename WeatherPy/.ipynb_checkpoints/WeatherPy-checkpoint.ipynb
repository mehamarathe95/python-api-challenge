# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#delcaring the units of the temperature to imperial and bringin in url
temp_units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

#defining the query that will be used in the loop below
query_url = url + "appid=" + weather_api_key + "&units=" + temp_units + "&q="

# %%
#setting up the lists that will be used for the dataframe
new_cities = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#setting the counts
set_count = 1
record_count = 0

#creating the for loop
print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    if record_count <50:
        
        record_count += 1
    
    else:
        
        set_count = set_count +1
        record_count = 0
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    try: 
        
        response = requests.get(query_url + city).json()
        new_cities.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    
    except:
        print(f"City not found. Skipping...")
    
        pass
              
print(f"-----------------------------")
print(f"Data Retrieval Complete")     
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | mehamn
# Processing Record 3 of Set 1 | college
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | xichang
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | impfondo
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | villarrica
# Processing Record 11 of Set 1 | akyab
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | naples
# Processing Record 15 of Set 1 | rabo de peixe
# Processing Record 16 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | algete
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | biak
# Processing Record 22 of Set 1 | waterloo
# Processing Record 23 of Set 1 | kaeo
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | marfino
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | martapura
# Processing Record 31 of Set 1 | barao de melgaco
# Processing Record 32 of Set 1 | te anau
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | vila franca do campo
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | maraba
# Processing Record 39 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | evanston
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | ewa beach
# Processing Record 46 of Set 1 | karratha
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | xuddur
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 0 of Set 2 | salinopolis
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | nioro
# Processing Record 3 of Set 2 | chokwe
# Processing Record 4 of Set 2 | mragowo
# Processing Record 5 of Set 2 | hinton
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | port hedland
# Processing Record 8 of Set 2 | portel
# Processing Record 9 of Set 2 | abong mbang
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | sinop
# Processing Record 12 of Set 2 | banjar
# Processing Record 13 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | terrace
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | santa maria
# Processing Record 18 of Set 2 | wanaka
# Processing Record 19 of Set 2 | parry sound
# Processing Record 20 of Set 2 | takoradi
# Processing Record 21 of Set 2 | jandaia do sul
# Processing Record 22 of Set 2 | tessalit
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | ola
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 2 | calama
# Processing Record 28 of Set 2 | henderson
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | dongying
# Processing Record 32 of Set 2 | algeciras
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | rocca priora
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | los llanos de aridane
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | cugir
# Processing Record 41 of Set 2 | port hardy
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | klaksvik
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | carballo
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | quijingue
# Processing Record 50 of Set 2 | caborca
# Processing Record 0 of Set 3 | barcelos
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | urumqi
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | kindu
# Processing Record 6 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 3 | palana
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 3 | menongue
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | tendukheda
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | tazovskiy
# Processing Record 20 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 3 | benguela
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | fare
# Processing Record 24 of Set 3 | tecolutilla
# Processing Record 25 of Set 3 | lekoni
# Processing Record 26 of Set 3 | salekhard
# Processing Record 27 of Set 3 | zharkent
# Processing Record 28 of Set 3 | havre-saint-pierre
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | ust-kan
# Processing Record 32 of Set 3 | alto araguaia
# Processing Record 33 of Set 3 | umm lajj
# Processing Record 34 of Set 3 | aktau
# Processing Record 35 of Set 3 | hobart
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | urengoy
# Processing Record 38 of Set 3 | atuona
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | ixtapa
# Processing Record 43 of Set 3 | grajau
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | portland
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | baculin
# Processing Record 49 of Set 3 | jand
# Processing Record 50 of Set 3 | kavieng
# Processing Record 0 of Set 4 | safaga
# Processing Record 1 of Set 4 | nouakchott
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | qujing
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | acapulco
# Processing Record 6 of Set 4 | broome
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | goulburn
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | hohhot
# Processing Record 14 of Set 4 | ojinaga
# Processing Record 15 of Set 4 | kununurra
# Processing Record 16 of Set 4 | halifax
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | nhulunbuy
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | aleksandrovskoye
# Processing Record 21 of Set 4 | saldanha
# Processing Record 22 of Set 4 | imbituba
# Processing Record 23 of Set 4 | pochutla
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | bilibino
# Processing Record 27 of Set 4 | belyy yar
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | terre haute
# Processing Record 30 of Set 4 | launceston
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 4 | dauriya
# Processing Record 34 of Set 4 | limbang
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | namatanai
# Processing Record 38 of Set 4 | novaya ladoga
# Processing Record 39 of Set 4 | camopi
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | dhidhdhoo
# Processing Record 42 of Set 4 | mana
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | timberlake
# Processing Record 45 of Set 4 | gornopravdinsk
# Processing Record 46 of Set 4 | whitehorse
# Processing Record 47 of Set 4 | riyadh
# Processing Record 48 of Set 4 | cockburn town
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | guozhen
# Processing Record 0 of Set 5 | chicama
# Processing Record 1 of Set 5 | wasilla
# Processing Record 2 of Set 5 | la baneza
# Processing Record 3 of Set 5 | ati
# Processing Record 4 of Set 5 | boralday
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | fallon
# Processing Record 7 of Set 5 | bakchar
# Processing Record 8 of Set 5 | cartagena del chaira
# Processing Record 9 of Set 5 | abu samrah
# Processing Record 10 of Set 5 | ratnagiri
# Processing Record 11 of Set 5 | awbari
# Processing Record 12 of Set 5 | buala
# Processing Record 13 of Set 5 | sao filipe
# Processing Record 14 of Set 5 | xining
# Processing Record 15 of Set 5 | tabou
# Processing Record 16 of Set 5 | huarmey
# Processing Record 17 of Set 5 | mabaruma
# Processing Record 18 of Set 5 | rincon
# Processing Record 19 of Set 5 | avarua
# Processing Record 20 of Set 5 | kodinsk
# Processing Record 21 of Set 5 | tari
# Processing Record 22 of Set 5 | yabelo
# Processing Record 23 of Set 5 | namie
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | koumac
# Processing Record 26 of Set 5 | kamaishi
# Processing Record 27 of Set 5 | carupano
# Processing Record 28 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 5 | prieska
# Processing Record 30 of Set 5 | teguise
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | olafsvik
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | byron bay
# Processing Record 37 of Set 5 | vardo
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | auki
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | waipawa
# Processing Record 43 of Set 5 | draguignan
# Processing Record 44 of Set 5 | hilo
# Processing Record 45 of Set 5 | khanskaya
# Processing Record 46 of Set 5 | alakurtti
# Processing Record 47 of Set 5 | kihei
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | hami
# Processing Record 50 of Set 5 | predivinsk
# Processing Record 0 of Set 6 | jiangyou
# Processing Record 1 of Set 6 | kirakira
# Processing Record 2 of Set 6 | malanje
# Processing Record 3 of Set 6 | vysokogornyy
# Processing Record 4 of Set 6 | orlik
# Processing Record 5 of Set 6 | kalmunai
# Processing Record 6 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 7 of Set 6 | qandala
# Processing Record 8 of Set 6 | ilhabela
# Processing Record 9 of Set 6 | pontes e lacerda
# Processing Record 10 of Set 6 | burns lake
# Processing Record 11 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 6 | anadyr
# Processing Record 13 of Set 6 | hervey bay
# Processing Record 14 of Set 6 | puerto ayora
# Processing Record 15 of Set 6 | kachug
# Processing Record 16 of Set 6 | cap malheureux
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | houma
# Processing Record 19 of Set 6 | teya
# Processing Record 20 of Set 6 | upernavik
# Processing Record 21 of Set 6 | berdychiv
# Processing Record 22 of Set 6 | alofi
# Processing Record 23 of Set 6 | bahia blanca
# Processing Record 24 of Set 6 | vaitape
# Processing Record 25 of Set 6 | tabanan
# Processing Record 26 of Set 6 | san policarpo
# Processing Record 27 of Set 6 | morant bay
# Processing Record 28 of Set 6 | camana
# Processing Record 29 of Set 6 | poltavka
# Processing Record 30 of Set 6 | opuwo
# Processing Record 31 of Set 6 | nuuk
# Processing Record 32 of Set 6 | inhambane
# Processing Record 33 of Set 6 | shache
# Processing Record 34 of Set 6 | mareeba
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | homagama
# Processing Record 37 of Set 6 | najran
# Processing Record 38 of Set 6 | katsuura
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | balakhta
# Processing Record 42 of Set 6 | colares
# Processing Record 43 of Set 6 | bonfim
# Processing Record 44 of Set 6 | beitbridge
# Processing Record 45 of Set 6 | suhbaatar
# Processing Record 46 of Set 6 | zunyi
# Processing Record 47 of Set 6 | mayo
# Processing Record 48 of Set 6 | kuala kedah
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | kota belud
# Processing Record 0 of Set 7 | fuerte
# Processing Record 1 of Set 7 | rodrigues alves
# Processing Record 2 of Set 7 | calabozo
# Processing Record 3 of Set 7 | havelock
# Processing Record 4 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 7 | rehoboth
# Processing Record 6 of Set 7 | kapit
# Processing Record 7 of Set 7 | salgueiro
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | morro bay
# Processing Record 10 of Set 7 | bambous virieux
# Processing Record 11 of Set 7 | bagdarin
# Processing Record 12 of Set 7 | quelimane
# Processing Record 13 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 7 | ilulissat
# Processing Record 15 of Set 7 | esmeraldas
# Processing Record 16 of Set 7 | san francisco del mar
# Processing Record 17 of Set 7 | novoagansk
# Processing Record 18 of Set 7 | manggar
# Processing Record 19 of Set 7 | juneau
# Processing Record 20 of Set 7 | nakama
# Processing Record 21 of Set 7 | balkanabat
# Processing Record 22 of Set 7 | westport
# Processing Record 23 of Set 7 | manamadurai
# Processing Record 24 of Set 7 | rocha
# Processing Record 25 of Set 7 | san quintin
# Processing Record 26 of Set 7 | nsoko
# Processing Record 27 of Set 7 | masallatah
# Processing Record 28 of Set 7 | karachi
# Processing Record 29 of Set 7 | port elizabeth
# Processing Record 30 of Set 7 | paltinoasa
# Processing Record 31 of Set 7 | rio gallegos
# Processing Record 32 of Set 7 | kutum
# Processing Record 33 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 7 | olga
# Processing Record 35 of Set 7 | madang
# Processing Record 36 of Set 7 | chokurdakh
# Processing Record 37 of Set 7 | haicheng
# Processing Record 38 of Set 7 | garwa
# Processing Record 39 of Set 7 | jalu
# Processing Record 40 of Set 7 | norman wells
# Processing Record 41 of Set 7 | laguna
# Processing Record 42 of Set 7 | huinan
# Processing Record 43 of Set 7 | vadum
# Processing Record 44 of Set 7 | antsohihy
# Processing Record 45 of Set 7 | tasiilaq
# Processing Record 46 of Set 7 | bonthe
# Processing Record 47 of Set 7 | odweyne
# Processing Record 48 of Set 7 | tame
# Processing Record 49 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 7 | sinnamary
# Processing Record 0 of Set 8 | san patricio
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | dolzhanskaya
# Processing Record 3 of Set 8 | balykshi
# City not found. Skipping...
# Processing Record 4 of Set 8 | souillac
# Processing Record 5 of Set 8 | lokosovo
# Processing Record 6 of Set 8 | storm lake
# Processing Record 7 of Set 8 | semey
# Processing Record 8 of Set 8 | lagos
# Processing Record 9 of Set 8 | suntar
# Processing Record 10 of Set 8 | nefteyugansk
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | arman
# Processing Record 13 of Set 8 | shizunai
# Processing Record 14 of Set 8 | poum
# Processing Record 15 of Set 8 | mount gambier
# Processing Record 16 of Set 8 | mpongwe
# Processing Record 17 of Set 8 | saskylakh
# Processing Record 18 of Set 8 | bose
# Processing Record 19 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 8 | tynda
# Processing Record 21 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 8 | namibe
# Processing Record 23 of Set 8 | mogadishu
# Processing Record 24 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 25 of Set 8 | gat
# Processing Record 26 of Set 8 | ileza
# Processing Record 27 of Set 8 | borovoy
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | khandyga
# Processing Record 30 of Set 8 | codrington
# Processing Record 31 of Set 8 | okha
# Processing Record 32 of Set 8 | marienburg
# Processing Record 33 of Set 8 | padre bernardo
# Processing Record 34 of Set 8 | mitsamiouli
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | wajima
# Processing Record 37 of Set 8 | anori
# Processing Record 38 of Set 8 | kirovskiy
# Processing Record 39 of Set 8 | holme
# Processing Record 40 of Set 8 | simpang
# Processing Record 41 of Set 8 | luganville
# Processing Record 42 of Set 8 | ouro fino
# Processing Record 43 of Set 8 | ullapool
# Processing Record 44 of Set 8 | santa rosa
# Processing Record 45 of Set 8 | calarasi
# Processing Record 46 of Set 8 | verkhniy avzyan
# Processing Record 47 of Set 8 | kosonsoy
# Processing Record 48 of Set 8 | liverpool
# Processing Record 49 of Set 8 | texas city
# Processing Record 50 of Set 8 | turayf
# Processing Record 0 of Set 9 | fethiye
# Processing Record 1 of Set 9 | kargopol
# Processing Record 2 of Set 9 | san carlos de bariloche
# Processing Record 3 of Set 9 | pudozh
# Processing Record 4 of Set 9 | rawah
# Processing Record 5 of Set 9 | ulaanbaatar
# Processing Record 6 of Set 9 | lagoa
# Processing Record 7 of Set 9 | bairiki
# Processing Record 8 of Set 9 | pampa
# Processing Record 9 of Set 9 | margate
# Processing Record 10 of Set 9 | teguldet
# Processing Record 11 of Set 9 | bom jesus
# Processing Record 12 of Set 9 | portales
# Processing Record 13 of Set 9 | mutis
# Processing Record 14 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 15 of Set 9 | russell
# Processing Record 16 of Set 9 | saint george
# Processing Record 17 of Set 9 | saint-louis
# Processing Record 18 of Set 9 | yakovlevka
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 21 of Set 9 | olinda
# Processing Record 22 of Set 9 | patitirion
# Processing Record 23 of Set 9 | sitka
# Processing Record 24 of Set 9 | winnemucca
# Processing Record 25 of Set 9 | dolores
# Processing Record 26 of Set 9 | waddan
# Processing Record 27 of Set 9 | saint-denis
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 9 | tancanhuitz
# Processing Record 31 of Set 9 | tshane
# Processing Record 32 of Set 9 | harper
# Processing Record 33 of Set 9 | krasnoselkup
# Processing Record 34 of Set 9 | novyy urengoy
# Processing Record 35 of Set 9 | shenjiamen
# Processing Record 36 of Set 9 | dubbo
# Processing Record 37 of Set 9 | cabo san lucas
# Processing Record 38 of Set 9 | pangody
# Processing Record 39 of Set 9 | sawakin
# Processing Record 40 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | bolondron
# Processing Record 42 of Set 9 | sorland
# Processing Record 43 of Set 9 | semnan
# Processing Record 44 of Set 9 | aykhal
# Processing Record 45 of Set 9 | deputatskiy
# Processing Record 46 of Set 9 | sao borja
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | ust-tsilma
# Processing Record 49 of Set 9 | mehran
# Processing Record 50 of Set 9 | santa marta
# Processing Record 0 of Set 10 | warrington
# Processing Record 1 of Set 10 | myingyan
# Processing Record 2 of Set 10 | ribeirao branco
# Processing Record 3 of Set 10 | victoria
# Processing Record 4 of Set 10 | andenes
# Processing Record 5 of Set 10 | sundargarh
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | narodychi
# Processing Record 8 of Set 10 | trelew
# Processing Record 9 of Set 10 | bull savanna
# Processing Record 10 of Set 10 | uzhur
# Processing Record 11 of Set 10 | stykkisholmur
# Processing Record 12 of Set 10 | kokopo
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | quang ngai
# Processing Record 15 of Set 10 | gamba
# Processing Record 16 of Set 10 | boljarovo
# City not found. Skipping...
# Processing Record 17 of Set 10 | jiayuguan
# Processing Record 18 of Set 10 | gizo
# Processing Record 19 of Set 10 | cabedelo
# Processing Record 20 of Set 10 | sijunjung
# Processing Record 21 of Set 10 | black river
# Processing Record 22 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | kangaatsiaq
# Processing Record 25 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 10 | parrita
# Processing Record 27 of Set 10 | mount pleasant
# Processing Record 28 of Set 10 | natchitoches
# Processing Record 29 of Set 10 | elko
# Processing Record 30 of Set 10 | podgorenskiy
# Processing Record 31 of Set 10 | beringovskiy
# Processing Record 32 of Set 10 | songjianghe
# Processing Record 33 of Set 10 | vao
# Processing Record 34 of Set 10 | karoi
# Processing Record 35 of Set 10 | conde
# Processing Record 36 of Set 10 | honiara
# Processing Record 37 of Set 10 | saint-francois
# Processing Record 38 of Set 10 | ejura
# Processing Record 39 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 10 | agva
# City not found. Skipping...
# Processing Record 43 of Set 10 | bajil
# Processing Record 44 of Set 10 | maniitsoq
# Processing Record 45 of Set 10 | naze
# Processing Record 46 of Set 10 | moree
# Processing Record 47 of Set 10 | tarbagatay
# Processing Record 48 of Set 10 | baykit
# Processing Record 49 of Set 10 | carauari
# Processing Record 50 of Set 10 | burica
# City not found. Skipping...
# Processing Record 0 of Set 11 | mazatlan
# Processing Record 1 of Set 11 | japura
# Processing Record 2 of Set 11 | belchatow
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | vostok
# Processing Record 5 of Set 11 | tecpan
# Processing Record 6 of Set 11 | yumen
# Processing Record 7 of Set 11 | hamilton
# Processing Record 8 of Set 11 | santa fe
# Processing Record 9 of Set 11 | weiden
# Processing Record 10 of Set 11 | segezha
# Processing Record 11 of Set 11 | puerto ayacucho
# Processing Record 12 of Set 11 | santa flavia
# Processing Record 13 of Set 11 | porbandar
# Processing Record 14 of Set 11 | yulara
# Processing Record 15 of Set 11 | labuhan
# Processing Record 16 of Set 11 | guilin
# Processing Record 17 of Set 11 | greenfield
# Processing Record 18 of Set 11 | valparaiso
# Processing Record 19 of Set 11 | faya
# Processing Record 20 of Set 11 | buenos aires
# Processing Record 21 of Set 11 | qaqortoq
# Processing Record 22 of Set 11 | belmonte
# Processing Record 23 of Set 11 | cabinda
# Processing Record 24 of Set 11 | chotila
# Processing Record 25 of Set 11 | biltine
# Processing Record 26 of Set 11 | vanimo
# Processing Record 27 of Set 11 | alexandria
# Processing Record 28 of Set 11 | surt
# Processing Record 29 of Set 11 | tignere
# Processing Record 30 of Set 11 | tabuk
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | niquero
# Processing Record 33 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 11 | skelleftea
# Processing Record 35 of Set 11 | leon
# Processing Record 36 of Set 11 | rio tercero
# Processing Record 37 of Set 11 | kosh-agach
# Processing Record 38 of Set 11 | vila
# Processing Record 39 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 40 of Set 11 | asilah
# Processing Record 41 of Set 11 | aldan
# Processing Record 42 of Set 11 | yaan
# Processing Record 43 of Set 11 | kalaleh
# Processing Record 44 of Set 11 | sabha
# Processing Record 45 of Set 11 | rafaela
# Processing Record 46 of Set 11 | nabire
# Processing Record 47 of Set 11 | port macquarie
# Processing Record 48 of Set 11 | teahupoo
# Processing Record 49 of Set 11 | kokoda
# Processing Record 50 of Set 11 | kroderen
# City not found. Skipping...
# Processing Record 0 of Set 12 | chapais
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | taburao
# City not found. Skipping...
# Processing Record 3 of Set 12 | agirish
# Processing Record 4 of Set 12 | brae
# Processing Record 5 of Set 12 | celestun
# Processing Record 6 of Set 12 | vestmannaeyjar
# Processing Record 7 of Set 12 | bayonet point
# Processing Record 8 of Set 12 | kurush
# Processing Record 9 of Set 12 | locri
# Processing Record 10 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 12 | marivan
# Processing Record 12 of Set 12 | angoche
# Processing Record 13 of Set 12 | pocoes
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | phayao
# Processing Record 16 of Set 12 | hecun
# Processing Record 17 of Set 12 | amazar
# Processing Record 18 of Set 12 | manali
# Processing Record 19 of Set 12 | nizhniy kuranakh
# Processing Record 20 of Set 12 | trofors
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | hofn
# Processing Record 23 of Set 12 | vestmanna
# Processing Record 24 of Set 12 | adrar
# Processing Record 25 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 12 | boende
# Processing Record 27 of Set 12 | jumla
# Processing Record 28 of Set 12 | saint-augustin
# Processing Record 29 of Set 12 | ebebiyin
# Processing Record 30 of Set 12 | dubai
# Processing Record 31 of Set 12 | hualmay
# Processing Record 32 of Set 12 | arlit
# Processing Record 33 of Set 12 | chama
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | pedra azul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#making the new DataFrame with above information
new_city_data = pd.DataFrame({
    "City": new_cities,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})


#new_city_data_df.count()

#showing the new dataframe
new_city_data.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0       Bethel     41.37     -73.41     46.00        81           1
# 1       Mehamn     71.04      27.85     42.82        82          82
# 2      College     64.86    -147.80     50.00        61          75
# 3  Provideniya     64.38    -173.30     44.60        65          75
# 4       Touros     -5.20     -35.46     77.00        83          40
#
#    Wind Speed Country        Date
# 0        5.82      US  1600653957
# 1       16.20      NO  1600654009
# 2        1.77      US  1600654010
# 3        8.95      RU  1600654010
# 4       11.41      BR  1600654010

# %%
#exporting the new dataframe into a csv file
new_city_data.to_csv("../output_data/cities_csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_100 = new_city_data.loc[new_city_data["Humidity"] >= 100]

print(humidity_100)

#there are no cities that have humidty over 100%. there are 13 cities
#have humidty at 100%
# Out:
#            City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 16       Algete     40.60      -3.50     59.00       100          84
# 83   Port Hardy     50.70    -127.42     53.60       100          90
# 86     Klaksvík     62.23      -6.59     51.80       100         100
# 88     Carballo     43.21      -8.69     62.60       100          75
# 93     Barcelos     41.54      -8.62     61.00       100          40
# 105  Tendūkheda     23.40      79.55     77.00       100          75
# 139      Broome     42.25     -75.83     44.01       100           0
# 150   Esperance    -33.87     121.90     53.60       100          75
# 184   La Bañeza     42.30      -5.90     55.40       100          12
# 224  Draguignan     43.53       6.47     64.40       100           0
# 229        Laas     46.62      10.70     57.20       100          75
# 355     Malbork     54.04      19.03     55.00       100           0
# 362       Holme     56.11      10.17     53.60       100          90
# 411   Bolondrón     22.76     -81.45     77.00       100          20
# 417  Hambantota      6.12      81.12     77.00       100          75
# 444     Parrita      9.52     -84.32     69.80       100         100
# 473      Weiden     49.68      12.16     46.99       100           1
# 488     Chotila     22.42      71.18     75.20       100          40
# 493     Tignère      7.37      12.65     63.63       100         100
# 515        Brae     60.40      -1.35     53.60       100         100
# 533   Vestmanna     62.16      -7.17     51.80       100         100
#
#      Wind Speed Country        Date
# 16         2.24      ES  1600654014
# 83         6.93      CA  1600654035
# 86        12.75      FO  1600654036
# 88         3.27      ES  1600654037
# 93         5.82      PT  1600654038
# 105        4.70      IN  1600654042
# 139        2.68      US  1600654052
# 150       14.99      AU  1600654057
# 184        4.29      ES  1600654066
# 224        3.36      FR  1600654078
# 229        4.70      IT  1600654079
# 355        2.24      PL  1600654117
# 362        3.36      DK  1600654119
# 411        5.82      CU  1600654132
# 417        4.70      LK  1600653966
# 444        1.12      CR  1600654143
# 473        4.92      DE  1600654153
# 488        3.36      IN  1600654158
# 493        2.66      CM  1600654159
# 515       13.87      GB  1600654166
# 533       12.75      FO  1600654171

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
from datetime import date

city_lat = new_city_data["Latitude"]
current_date = date.today()
today_date = current_date.strftime("%m/%d/%y")
temps = new_city_data["Max Temp"]

plt.scatter(city_lat, temps, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Max Temperature ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.temp.png')
plt.show()

# %% [markdown]
# This plot shows that the temperature is a lot warmer as the cities approach the latitude 0, which is the equator. There is a positive correlation between latitude approaching 0 and temperature increasing.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_humidity = new_city_data["Humidity"]

plt.scatter(city_lat, city_humidity, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Humidity ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.humidity.png')
plt.show()

# %% [markdown]
# This scatter plot is very ambigious and shows little to no correlation between latitude and humidit levels. Most locations have a humidity above 40%.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_cloudiness = new_city_data["Cloudiness"]

plt.scatter(city_lat, city_cloudiness, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Cloudiness ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.cloudiness.png')
plt.show()

# %% [markdown]
# More than humidity, the latitude vs. cloudiness plot is ambigious and shows absolutely no correlation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_windspeed = new_city_data["Wind Speed"]

plt.scatter(city_lat, city_windspeed, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Wind Speed ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.windspeed.png')
plt.show()

# %% [markdown]
# This scatter plot shows that the wind speeds are mostly between 0-10 mph for most locations. There are a few outlier locations that have wind speeds above 20 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_reg_plot(x_values, y_values, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.05, 0.13), xycoords='axes fraction', fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.title(title)
    print(f"The r-squared is: {rvalue}")
    plt.savefig(f"../Images/{title}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemp = new_city_data.loc[new_city_data["Latitude"] > 0]
south_hemp = new_city_data.loc[new_city_data["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"))
# Out:
# The r-squared is: -0.8417749751875716
# None

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.7443413535384416
# None

# %% [markdown]
# Both linear regression plots demonstrate as location latitude's reach closer to 0 latitude, the temperature equally increases. This is a positive correlation between max temp and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Humidity"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.025172945484692184
# None

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Humidity"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.20085765592643248
# None

# %% [markdown]
# The northern hemisphere regression plot for humidity shows no correlation between humidity and latitude. This can also be seen because the slope is very small (0.02). For the southern hemisphere, there seems to be a little correlation as the slop slightly increases (0.27). Overall, there is minimal correlation between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Cloudiness"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.07952330873391561
# None

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Cloudiness"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.16793704436385604
# None

# %% [markdown]
# In both plots, there is a small correlation of the cloudiness increasing as locations get closer to 0 latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Wind Speed"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.125904900061436
# None

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Wind Speed"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: -0.16502191001407954
# None

# %% [markdown]
# In the first plot, there seems to be correlation between latitude and wind speeds. However, there is a small correlation in the southern hemisphere plot as the slope is going downwards - As the latitude reaches 0, the max temp also drops.
