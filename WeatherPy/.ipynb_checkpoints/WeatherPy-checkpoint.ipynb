# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#delcaring the units of the temperature to imperial and bringin in url
temp_units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

#defining the query that will be used in the loop below
query_url = url + "appid=" + weather_api_key + "&units=" + temp_units + "&q="

# %%
#setting up the lists that will be used for the dataframe
new_cities = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#setting the counts
set_count = 1
record_count = 0

#creating the for loop
print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    if record_count <50:
        
        record_count += 1
    
    else:
        
        set_count = set_count +1
        record_count = 0
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    try: 
        
        response = requests.get(query_url + city).json()
        new_cities.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    
    except:
        print(f"City not found. Skipping...")
    
        pass
              
print(f"-----------------------------")
print(f"Data Retrieval Complete")     
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | krasnokamensk
# Processing Record 6 of Set 1 | marrakesh
# Processing Record 7 of Set 1 | mocuba
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | ayan
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | avera
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | astana
# Processing Record 21 of Set 1 | cap malheureux
# Processing Record 22 of Set 1 | okha
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | bafra
# Processing Record 26 of Set 1 | charters towers
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | kuvandyk
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | saint-georges
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | brenham
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | marzuq
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | portel
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | mehamn
# Processing Record 42 of Set 1 | quatre cocos
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | bajil
# Processing Record 47 of Set 1 | idil
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | shenzhen
# Processing Record 1 of Set 2 | noumea
# Processing Record 2 of Set 2 | aquidauana
# Processing Record 3 of Set 2 | vila velha
# Processing Record 4 of Set 2 | kirovskiy
# Processing Record 5 of Set 2 | shimoda
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | peace river
# Processing Record 8 of Set 2 | atar
# Processing Record 9 of Set 2 | kajaani
# Processing Record 10 of Set 2 | mogwase
# Processing Record 11 of Set 2 | williston
# Processing Record 12 of Set 2 | matara
# Processing Record 13 of Set 2 | valdez
# Processing Record 14 of Set 2 | urfa
# City not found. Skipping...
# Processing Record 15 of Set 2 | kumylzhenskaya
# Processing Record 16 of Set 2 | campagna
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | vanimo
# Processing Record 23 of Set 2 | port macquarie
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | alice springs
# Processing Record 26 of Set 2 | vagur
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | innisfail
# Processing Record 29 of Set 2 | najran
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | wakkanai
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | anif
# Processing Record 36 of Set 2 | pasni
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | salekhard
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | nelson
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | barinas
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | inirida
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | maceio
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 0 of Set 3 | kesennuma
# City not found. Skipping...
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | alyangula
# Processing Record 7 of Set 3 | san luis
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | sisimiut
# Processing Record 10 of Set 3 | krizevci
# Processing Record 11 of Set 3 | gambela
# Processing Record 12 of Set 3 | kuusamo
# Processing Record 13 of Set 3 | omsukchan
# Processing Record 14 of Set 3 | rawson
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | mezen
# Processing Record 17 of Set 3 | tabora
# Processing Record 18 of Set 3 | wagga wagga
# Processing Record 19 of Set 3 | kautokeino
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | mareeba
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | camana
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | tourlaville
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 3 | saint-joseph
# Processing Record 31 of Set 3 | stephenville crossing
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | vanderhoof
# Processing Record 35 of Set 3 | birjand
# Processing Record 36 of Set 3 | beloha
# Processing Record 37 of Set 3 | port blair
# Processing Record 38 of Set 3 | evensk
# Processing Record 39 of Set 3 | leningradskiy
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | constitucion
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | fergus falls
# Processing Record 44 of Set 3 | whitley bay
# Processing Record 45 of Set 3 | donskoye
# Processing Record 46 of Set 3 | porto belo
# Processing Record 47 of Set 3 | awjilah
# Processing Record 48 of Set 3 | duluth
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | punta alta
# Processing Record 0 of Set 4 | beyneu
# Processing Record 1 of Set 4 | anchorage
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | flinders
# Processing Record 4 of Set 4 | laguna
# Processing Record 5 of Set 4 | zamora
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | olinda
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | chimbote
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | ongandjera
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | jalu
# Processing Record 14 of Set 4 | altamont
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | macenta
# Processing Record 17 of Set 4 | hobbs
# Processing Record 18 of Set 4 | tilichiki
# Processing Record 19 of Set 4 | kuah
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | merauke
# Processing Record 22 of Set 4 | srikakulam
# Processing Record 23 of Set 4 | kouvola
# Processing Record 24 of Set 4 | papara
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | dudinka
# Processing Record 27 of Set 4 | qasigiannguit
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | mandal
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | puerto penasco
# Processing Record 35 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 4 | ekhabi
# Processing Record 39 of Set 4 | moose factory
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | lasa
# Processing Record 42 of Set 4 | lorengau
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | ornskoldsvik
# Processing Record 45 of Set 4 | tucupita
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | porto santo
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | araouane
# Processing Record 50 of Set 4 | ancona
# Processing Record 0 of Set 5 | talara
# Processing Record 1 of Set 5 | sobolevo
# Processing Record 2 of Set 5 | suez
# Processing Record 3 of Set 5 | butaritari
# Processing Record 4 of Set 5 | boende
# Processing Record 5 of Set 5 | puta
# Processing Record 6 of Set 5 | calama
# Processing Record 7 of Set 5 | sehithwa
# Processing Record 8 of Set 5 | san diego de los banos
# Processing Record 9 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 5 | havoysund
# Processing Record 11 of Set 5 | tungor
# Processing Record 12 of Set 5 | dunnville
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 5 | salina cruz
# Processing Record 17 of Set 5 | kayseri
# Processing Record 18 of Set 5 | cruzeiro do sul
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | bar harbor
# Processing Record 21 of Set 5 | lethem
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | sabang
# Processing Record 24 of Set 5 | barrancabermeja
# Processing Record 25 of Set 5 | bambanglipuro
# Processing Record 26 of Set 5 | skjervoy
# Processing Record 27 of Set 5 | hilo
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 30 of Set 5 | antofagasta
# Processing Record 31 of Set 5 | fegyvernek
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | andenes
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | nelson bay
# Processing Record 38 of Set 5 | korla
# Processing Record 39 of Set 5 | pathein
# Processing Record 40 of Set 5 | halifax
# Processing Record 41 of Set 5 | nanortalik
# Processing Record 42 of Set 5 | samarai
# Processing Record 43 of Set 5 | katangli
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | wladyslawowo
# Processing Record 46 of Set 5 | kahului
# Processing Record 47 of Set 5 | green valley
# Processing Record 48 of Set 5 | rongcheng
# Processing Record 49 of Set 5 | paamiut
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 0 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 6 | atasu
# Processing Record 2 of Set 6 | talaya
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | fort nelson
# Processing Record 5 of Set 6 | leczyca
# Processing Record 6 of Set 6 | zhigansk
# Processing Record 7 of Set 6 | sillod
# Processing Record 8 of Set 6 | kismayo
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | nantucket
# Processing Record 12 of Set 6 | svatove
# Processing Record 13 of Set 6 | nyurba
# Processing Record 14 of Set 6 | aleksandrov gay
# Processing Record 15 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 6 | livingstonia
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | alugan
# Processing Record 20 of Set 6 | port-cartier
# Processing Record 21 of Set 6 | quang ngai
# Processing Record 22 of Set 6 | buala
# Processing Record 23 of Set 6 | cabedelo
# Processing Record 24 of Set 6 | flin flon
# Processing Record 25 of Set 6 | esperance
# Processing Record 26 of Set 6 | port hedland
# Processing Record 27 of Set 6 | roma
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | iralaya
# Processing Record 32 of Set 6 | vostok
# Processing Record 33 of Set 6 | necochea
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | mazatan
# Processing Record 36 of Set 6 | graaff-reinet
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | abha
# Processing Record 39 of Set 6 | trelleborg
# Processing Record 40 of Set 6 | edelira
# Processing Record 41 of Set 6 | moron
# Processing Record 42 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 6 | muros
# Processing Record 44 of Set 6 | saint-augustin
# Processing Record 45 of Set 6 | chipinge
# Processing Record 46 of Set 6 | vadlapudi
# Processing Record 47 of Set 6 | awbari
# Processing Record 48 of Set 6 | chuncheng
# Processing Record 49 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 6 | danville
# Processing Record 0 of Set 7 | haukipudas
# Processing Record 1 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 7 | vire
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | carora
# Processing Record 5 of Set 7 | shizunai
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | dordrecht
# Processing Record 8 of Set 7 | balgazyn
# Processing Record 9 of Set 7 | russell
# Processing Record 10 of Set 7 | agadir
# Processing Record 11 of Set 7 | poya
# Processing Record 12 of Set 7 | road town
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | lusambo
# Processing Record 15 of Set 7 | santa engracia
# Processing Record 16 of Set 7 | mugur-aksy
# Processing Record 17 of Set 7 | bubaque
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | martapura
# Processing Record 20 of Set 7 | panjab
# Processing Record 21 of Set 7 | narasannapeta
# Processing Record 22 of Set 7 | beringovskiy
# Processing Record 23 of Set 7 | vanavara
# Processing Record 24 of Set 7 | teya
# Processing Record 25 of Set 7 | san rafael
# Processing Record 26 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 7 | aklavik
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | waddan
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | nichinan
# Processing Record 32 of Set 7 | palana
# Processing Record 33 of Set 7 | gravdal
# Processing Record 34 of Set 7 | birao
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | saint-pierre
# Processing Record 37 of Set 7 | stamford
# Processing Record 38 of Set 7 | belaya gora
# Processing Record 39 of Set 7 | bokhan
# Processing Record 40 of Set 7 | vadastrita
# Processing Record 41 of Set 7 | polunochnoye
# Processing Record 42 of Set 7 | deputatskiy
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | torbay
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | mpongwe
# Processing Record 48 of Set 7 | pirganj
# Processing Record 49 of Set 7 | praia da vitoria
# Processing Record 50 of Set 7 | ippy
# Processing Record 0 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | jackson
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 5 of Set 8 | voh
# Processing Record 6 of Set 8 | padang
# Processing Record 7 of Set 8 | taklisah
# Processing Record 8 of Set 8 | dingle
# Processing Record 9 of Set 8 | skibbereen
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 8 | hengshui
# Processing Record 14 of Set 8 | yar-sale
# Processing Record 15 of Set 8 | umm lajj
# Processing Record 16 of Set 8 | ambilobe
# Processing Record 17 of Set 8 | ugoofaaru
# Processing Record 18 of Set 8 | cayenne
# Processing Record 19 of Set 8 | comodoro rivadavia
# Processing Record 20 of Set 8 | turgenevo
# Processing Record 21 of Set 8 | daru
# Processing Record 22 of Set 8 | sistranda
# Processing Record 23 of Set 8 | ribeira grande
# Processing Record 24 of Set 8 | dunedin
# Processing Record 25 of Set 8 | huarmey
# Processing Record 26 of Set 8 | kiunga
# Processing Record 27 of Set 8 | yarada
# Processing Record 28 of Set 8 | kavieng
# Processing Record 29 of Set 8 | manali
# Processing Record 30 of Set 8 | iberia
# Processing Record 31 of Set 8 | walvis bay
# Processing Record 32 of Set 8 | cairns
# Processing Record 33 of Set 8 | bambous virieux
# Processing Record 34 of Set 8 | biak
# Processing Record 35 of Set 8 | tierralta
# Processing Record 36 of Set 8 | kulhudhuffushi
# Processing Record 37 of Set 8 | uthal
# Processing Record 38 of Set 8 | sao joao da barra
# Processing Record 39 of Set 8 | borinskoye
# Processing Record 40 of Set 8 | coquimbo
# Processing Record 41 of Set 8 | kavaratti
# Processing Record 42 of Set 8 | igarka
# Processing Record 43 of Set 8 | marawi
# Processing Record 44 of Set 8 | ballina
# Processing Record 45 of Set 8 | bereda
# Processing Record 46 of Set 8 | tsaratanana
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 8 | luanda
# Processing Record 0 of Set 9 | malpe
# Processing Record 1 of Set 9 | nortelandia
# Processing Record 2 of Set 9 | hauzenberg
# Processing Record 3 of Set 9 | fukue
# Processing Record 4 of Set 9 | henties bay
# Processing Record 5 of Set 9 | irbit
# Processing Record 6 of Set 9 | parabel
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | bridgton
# Processing Record 9 of Set 9 | neuquen
# Processing Record 10 of Set 9 | kendari
# Processing Record 11 of Set 9 | hvide sande
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | sola
# Processing Record 14 of Set 9 | puerto colombia
# Processing Record 15 of Set 9 | mweka
# Processing Record 16 of Set 9 | sibu
# Processing Record 17 of Set 9 | rancho palos verdes
# Processing Record 18 of Set 9 | binzhou
# Processing Record 19 of Set 9 | kurilsk
# Processing Record 20 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 9 | khorramshahr
# Processing Record 22 of Set 9 | los lunas
# Processing Record 23 of Set 9 | makakilo city
# Processing Record 24 of Set 9 | broome
# Processing Record 25 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 9 | abu kamal
# Processing Record 27 of Set 9 | erenhot
# Processing Record 28 of Set 9 | isabela
# Processing Record 29 of Set 9 | baykalovo
# Processing Record 30 of Set 9 | maturin
# Processing Record 31 of Set 9 | zhangye
# Processing Record 32 of Set 9 | acapulco
# Processing Record 33 of Set 9 | baykit
# Processing Record 34 of Set 9 | margate
# Processing Record 35 of Set 9 | san quintin
# Processing Record 36 of Set 9 | waipawa
# Processing Record 37 of Set 9 | naze
# Processing Record 38 of Set 9 | norsup
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | mozarlandia
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | yunyang
# Processing Record 43 of Set 9 | mercedes
# Processing Record 44 of Set 9 | tateyama
# Processing Record 45 of Set 9 | igrim
# Processing Record 46 of Set 9 | misratah
# Processing Record 47 of Set 9 | ponta delgada
# Processing Record 48 of Set 9 | lazaro cardenas
# Processing Record 49 of Set 9 | skibotn
# Processing Record 50 of Set 9 | sorong
# Processing Record 0 of Set 10 | kudahuvadhoo
# Processing Record 1 of Set 10 | menongue
# Processing Record 2 of Set 10 | omboue
# Processing Record 3 of Set 10 | blackwater
# Processing Record 4 of Set 10 | ixtapa
# Processing Record 5 of Set 10 | melbourne
# Processing Record 6 of Set 10 | san jose
# Processing Record 7 of Set 10 | ostrovnoy
# Processing Record 8 of Set 10 | cajaruro
# Processing Record 9 of Set 10 | los llanos de aridane
# Processing Record 10 of Set 10 | portland
# Processing Record 11 of Set 10 | quelimane
# Processing Record 12 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | yulara
# Processing Record 14 of Set 10 | lattes
# Processing Record 15 of Set 10 | douentza
# Processing Record 16 of Set 10 | itarema
# Processing Record 17 of Set 10 | tlaxiaco
# City not found. Skipping...
# Processing Record 18 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 10 | paragominas
# Processing Record 20 of Set 10 | tempio pausania
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | zheleznodorozhnyy
# Processing Record 23 of Set 10 | san policarpo
# Processing Record 24 of Set 10 | karratha
# Processing Record 25 of Set 10 | valparaiso
# Processing Record 26 of Set 10 | bossier city
# Processing Record 27 of Set 10 | pochinok
# Processing Record 28 of Set 10 | mpika
# Processing Record 29 of Set 10 | korsakov
# Processing Record 30 of Set 10 | nishihara
# Processing Record 31 of Set 10 | faya
# Processing Record 32 of Set 10 | santa fe
# Processing Record 33 of Set 10 | makinsk
# Processing Record 34 of Set 10 | nola
# Processing Record 35 of Set 10 | maniitsoq
# Processing Record 36 of Set 10 | rantepao
# Processing Record 37 of Set 10 | astorga
# Processing Record 38 of Set 10 | tomatlan
# Processing Record 39 of Set 10 | pundaguitan
# Processing Record 40 of Set 10 | itupiranga
# Processing Record 41 of Set 10 | kushima
# Processing Record 42 of Set 10 | hambantota
# Processing Record 43 of Set 10 | sassandra
# Processing Record 44 of Set 10 | destin
# Processing Record 45 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 10 | adrar
# Processing Record 47 of Set 10 | pindiga
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 50 of Set 10 | ulaanbaatar
# Processing Record 0 of Set 11 | elmina
# Processing Record 1 of Set 11 | kodinsk
# Processing Record 2 of Set 11 | halenkov
# Processing Record 3 of Set 11 | hrusovany nad jevisovkou
# Processing Record 4 of Set 11 | wanning
# Processing Record 5 of Set 11 | rudbar
# Processing Record 6 of Set 11 | kargat
# Processing Record 7 of Set 11 | le port
# Processing Record 8 of Set 11 | tete
# Processing Record 9 of Set 11 | kotelnich
# Processing Record 10 of Set 11 | cherskiy
# Processing Record 11 of Set 11 | sinnamary
# Processing Record 12 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | moindou
# Processing Record 15 of Set 11 | goshogawara
# Processing Record 16 of Set 11 | iglesias
# Processing Record 17 of Set 11 | lock haven
# Processing Record 18 of Set 11 | auki
# Processing Record 19 of Set 11 | taltal
# Processing Record 20 of Set 11 | oranjemund
# Processing Record 21 of Set 11 | dolores
# Processing Record 22 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 11 | kifri
# Processing Record 24 of Set 11 | morondava
# Processing Record 25 of Set 11 | santa cruz
# Processing Record 26 of Set 11 | northam
# Processing Record 27 of Set 11 | gaborone
# Processing Record 28 of Set 11 | la palma
# Processing Record 29 of Set 11 | palembang
# Processing Record 30 of Set 11 | balkhash
# Processing Record 31 of Set 11 | dharchula
# Processing Record 32 of Set 11 | lumphat
# Processing Record 33 of Set 11 | letpadan
# Processing Record 34 of Set 11 | tadine
# Processing Record 35 of Set 11 | port hardy
# Processing Record 36 of Set 11 | khor
# Processing Record 37 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 11 | tucuman
# Processing Record 39 of Set 11 | derzhavinsk
# Processing Record 40 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 11 | dhanaura
# Processing Record 42 of Set 11 | bontang
# Processing Record 43 of Set 11 | sunrise manor
# Processing Record 44 of Set 11 | malakal
# Processing Record 45 of Set 11 | lichinga
# Processing Record 46 of Set 11 | eydhafushi
# Processing Record 47 of Set 11 | vredendal
# Processing Record 48 of Set 11 | guerrero negro
# Processing Record 49 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 11 | calvinia
# Processing Record 0 of Set 12 | talnakh
# Processing Record 1 of Set 12 | cooma
# Processing Record 2 of Set 12 | north platte
# Processing Record 3 of Set 12 | castelo do piaui
# Processing Record 4 of Set 12 | odweyne
# Processing Record 5 of Set 12 | chukhloma
# Processing Record 6 of Set 12 | mitsamiouli
# Processing Record 7 of Set 12 | port lincoln
# Processing Record 8 of Set 12 | port augusta
# Processing Record 9 of Set 12 | karagaylinskiy
# Processing Record 10 of Set 12 | tutoia
# Processing Record 11 of Set 12 | ailigandi
# Processing Record 12 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 12 | ishigaki
# Processing Record 14 of Set 12 | rockingham
# Processing Record 15 of Set 12 | poum
# Processing Record 16 of Set 12 | tucumcari
# Processing Record 17 of Set 12 | henzada
# City not found. Skipping...
# Processing Record 18 of Set 12 | sao miguel
# Processing Record 19 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 12 | alushta
# Processing Record 21 of Set 12 | imamoglu
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | rio grande
# Processing Record 24 of Set 12 | sibolga
# Processing Record 25 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 12 | katete
# Processing Record 27 of Set 12 | killybegs
# Processing Record 28 of Set 12 | adre
# Processing Record 29 of Set 12 | cukai
# Processing Record 30 of Set 12 | quepos
# Processing Record 31 of Set 12 | inongo
# Processing Record 32 of Set 12 | caravelas
# Processing Record 33 of Set 12 | cervo
# Processing Record 34 of Set 12 | kiama
# Processing Record 35 of Set 12 | robe
# Processing Record 36 of Set 12 | clarence town
# Processing Record 37 of Set 12 | banda aceh
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | mega
# Processing Record 40 of Set 12 | kamskiye polyany
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#making the new DataFrame with above information
new_city_data = pd.DataFrame({
    "City": new_cities,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})


#new_city_data_df.count()

#showing the new dataframe
new_city_data.head()
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0         Albany     42.60     -73.97     46.00        55           0
# 1      Mahébourg    -20.41      57.70     71.60        78          40
# 2        Mataura    -46.19     168.86     59.99        47          33
# 3         Lompoc     34.64    -120.46     68.00        87          75
# 4  Krasnokamensk     50.10     118.04     50.07        70         100
#
#    Wind Speed Country        Date
# 0        3.94      US  1600649819
# 1       11.41      MU  1600649820
# 2        8.08      NZ  1600649820
# 3       16.11      US  1600649775
# 4        3.27      RU  1600649820

# %%
#exporting the new dataframe into a csv file
new_city_data.to_csv("../output_data/cities_csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_100 = new_city_data.loc[new_city_data["Humidity"] >= 100]

print(humidity_100)

#there are no cities that have humidty over 100%. there are 13 cities
#have humidty at 100%
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 32       Brenham     30.17     -96.40     72.00       100          90
# 70   Clyde River     70.47     -68.59     21.20       100           1
# 83          Anif     47.75      13.07     55.99       100          20
# 178         Laas     46.62      10.70     57.20       100          75
# 248     Klaksvík     62.23      -6.59     51.80       100         100
# 256    Esperance    -33.87     121.90     51.80       100          90
# 269   Trelleborg     55.38      13.16     53.01       100          90
# 343      Cayenne      4.93     -52.33     78.80       100           0
# 352       Yārāda     17.65      83.27     78.80       100          90
# 370       Bereda     43.27      -7.54     61.00       100          99
# 451    Nishihara     26.18     127.76     84.20       100          75
# 463   Hambantota      6.12      81.12     75.20       100          90
# 503   Port Hardy     50.70    -127.42     55.40       100          90
#
#      Wind Speed Country        Date
# 32         6.93      US  1600649827
# 70         2.24      CA  1600649839
# 83         1.12      AT  1600649844
# 178        4.70      IT  1600649872
# 248       16.11      FO  1600649820
# 256       16.11      AU  1600649868
# 269        3.36      SE  1600649901
# 343        8.50      GF  1600649923
# 352        2.24      IN  1600649925
# 370        3.00      ES  1600649930
# 451       10.29      JP  1600649954
# 463        2.24      LK  1600649958
# 503        3.36      CA  1600649970

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
from datetime import date

city_lat = new_city_data["Latitude"]
current_date = date.today()
today_date = current_date.strftime("%m/%d/%y")
temps = new_city_data["Max Temp"]

plt.scatter(city_lat, temps, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Max Temperature ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_humidity = new_city_data["Humidity"]

plt.scatter(city_lat, city_humidity, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Humidity ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_cloudiness = new_city_data["Cloudiness"]

plt.scatter(city_lat, city_cloudiness, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Cloudiness ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_windspeed = new_city_data["Wind Speed"]

plt.scatter(city_lat, city_windspeed, alpha=.5, marker="o", color="blue", edgecolor="black")
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Wind Speed ({today_date})')
plt.grid(True)
plt.savefig('../Images/lat.windspeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_reg_plot(x_values, y_values, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.05, 0.13), xycoords='axes fraction', fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.title(title)
    print(f"The r-squared is: {rvalue}")
    plt.savefig(f"../Images/{title}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemp = new_city_data.loc[new_city_data["Latitude"] > 0]
south_hemp = new_city_data.loc[new_city_data["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"))
# Out:
# The r-squared is: -0.8362286042002663
# None

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.6904337254727486
# None

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Humidity"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.02933083745913203
# None

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Humidity"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.19140294194063837
# None

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Cloudiness"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: -0.021219886297334668
# None

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Cloudiness"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.17574036670853604
# None

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemp["Latitude"]
y_values = north_hemp["Wind Speed"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Northern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: 0.17083439003400144
# None

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemp["Latitude"]
y_values = south_hemp["Wind Speed"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values,
                     "Southern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression"))
# Out:
# The r-squared is: -0.15822205600423514
# None
